# %%
import pandas as pd
import os

# %%
df = pd.read_csv('./merged_output_1.csv', encoding='cp1252')

# %%
df.head()
# Out:
#                                 name                      name_for_emails  \
# 0                    AK Bouncy House                      Ak Bouncy House
# 1                 BAC Transportation                   Bac Transportation
# 2  Affordable & Luxury Event Rentals  Affordable And Luxury Event Rentals
# 3    Arkansas Inflatable Rentals LLC          Arkansas Inflatable Rentals
# 4                  Backyard Bash llc                        Backyard Bash
#
#                                     site  \
# 0        http://akbouncyhouserental.com/
# 1                   http://bactrans.com/
# 2             http://affordabletent.net/
# 3  http://arkansasinflatablerentals.com/
# 4         http://backyardbashrental.com/
#
#                                             subtypes  \
# 0  Bouncy castle hire, Party equipment rental ser...
# 1  Party equipment rental service, Bus charter, C...
# 2  Party equipment rental service, Tent rental se...
# ...

# %%
df[df["category_y"] == 7]

# pick a 100 random with category 7
df_7 = df[df["category_y"] == 7]

# %%
# df_7 = df_7[:100]

# %%
df_7.drop(columns=['category_y'], inplace=True)
# Out:
# /tmp/ipykernel_123814/675341707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_7.drop(columns=['category_y'], inplace=True)

# %%
df_7.to_csv('category_7.csv', index=False)
